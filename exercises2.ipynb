# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import statsmodels as sm

# %%
# Aquiring
df = pd.read_json("datasets/usda_food/database.json")
display(df.head())
# Out:
#      id                         description tags manufacturer  \
# 0  1008                     Cheese, caraway   []
# 1  1009                     Cheese, cheddar   []
# 2  1018                        Cheese, edam   []
# 3  1019                        Cheese, feta   []
# 4  1028  Cheese, mozzarella, part skim milk   []
#
#                     group                                           portions  \
# 0  Dairy and Egg Products      [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]
# 1  Dairy and Egg Products  [{'amount': 1, 'unit': 'cup, diced', 'grams': ...
# 2  Dairy and Egg Products  [{'amount': 1, 'unit': 'oz', 'grams': 28.35}, ...
# 3  Dairy and Egg Products  [{'amount': 1, 'unit': 'cup, crumbled', 'grams...
# 4  Dairy and Egg Products      [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]
#
#                                            nutrients
# 0  [{'value': 25.18, 'units': 'g', 'description':...
# 1  [{'value': 24.9, 'units': 'g', 'description': ...
# ...

# %%
df.loc[df["id"] == 1008, "portions"].at[0]
# Out:
# [{'amount': 1, 'unit': 'oz', 'grams': 28.35}]

# %%
display(df["group"].describe())
display(df["group"].unique())
# Out:
# count                                  6636
# unique                                   25
# top       Vegetables and Vegetable Products
# freq                                    812
# Name: group, dtype: object
# array(['Dairy and Egg Products', 'Spices and Herbs', 'Baby Foods',
#        'Fats and Oils', 'Poultry Products', 'Soups, Sauces, and Gravies',
#        'Sausages and Luncheon Meats', 'Breakfast Cereals',
#        'Fruits and Fruit Juices', 'Pork Products',
#        'Vegetables and Vegetable Products', 'Nut and Seed Products',
#        'Beef Products', 'Beverages', 'Finfish and Shellfish Products',
#        'Legumes and Legume Products', 'Lamb, Veal, and Game Products',
#        'Baked Products', 'Snacks', 'Sweets', 'Cereal Grains and Pasta',
#        'Fast Foods', 'Meals, Entrees, and Sidedishes', 'Ethnic Foods',
#        'Restaurant Foods'], dtype=object)

# %%
df["group"].value_counts().plot.pie(figsize=(10,40))
# Out:
# <AxesSubplot: ylabel='group'>
